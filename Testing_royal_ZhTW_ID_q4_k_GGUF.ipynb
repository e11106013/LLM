# %%
#@title 安裝軟體套件
# !pip install llama-cpp-python

# %%
#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

# %%
#@title 登入HF
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# ...

# %%
#@title 下載自HF下載模型
# !mkdir -p /content/models
# !huggingface-cli download roylin1003/royal-ZhTW-ID-q4_k_m --local-dir models
# Out:
# Fetching 3 files: 100% 3/3 [00:00<00:00, 1067.16it/s]
# /content/models

# %%
#@title 載入模型
from llama_cpp import Llama
llm = Llama(model_path="/content/models/royal-ZhTW-ID-q4_k_m.gguf")
# Out:
# llama_model_loader: loaded meta data with 27 key-value pairs and 339 tensors from /content/models/royal-ZhTW-ID-q4_k_m.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = qwen2
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Qwen2.5 7B Instruct
# llama_model_loader: - kv   3:                       general.organization str              = Qwen
# llama_model_loader: - kv   4:                           general.finetune str              = Instruct
# llama_model_loader: - kv   5:                           general.basename str              = Qwen2.5
# llama_model_loader: - kv   6:                         general.size_label str              = 7B
# ...

# %%
#@title 測試模型
output = llm("Q: 請翻譯印尼文:然而面臨到期債務壓力，可能影響其獲得補助資格。？\nA:", max_tokens=50)
print(output["choices"][0]["text"])
# Out:
# llama_perf_context_print:        load time =   10033.59 ms
# llama_perf_context_print: prompt eval time =   10032.96 ms /    30 tokens (  334.43 ms per token,     2.99 tokens per second)
# llama_perf_context_print:        eval time =   34902.98 ms /    49 runs   (  712.31 ms per token,     1.40 tokens per second)
# llama_perf_context_print:       total time =   45023.42 ms /    79 tokens
#  Namun, tekanan dari utang yang jatuh tempo dapat memengaruhi kelayakannya untuk menerima subsidi. 這段翻譯的意思是，如果債務壓力過大，可能會影響其獲得補助資
